# %%
import pandas as pd

# %%
# People: P1,P2,P3
# Age:    20,30,40

# %%
d = {'People':['P1','P2','P3'],'Age':[20,30,40]}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#   People  Age
# 0     P1   20
# 1     P2   30
# 2     P3   40

# %%
pd.read_excel("Sales_Data.xlsx")
# Out:
#   Order Date   Region Manager Name Salesman Name     Items  Units  Unit Price  \
# 0     3-5-24     East     John Doe         Alice    Laptop      5        1000
# 1     3-6-24  Central   Jane Smith           Bob   Monitor     10         200
# 2     3-6-24     East     John Doe       Charlie  Keyboard     15          50
# 3     3-7-24     West  Emily Clark         David     Mouse     20          20
# 4     3-8-24  Central   Jane Smith           Eve   Printer      2         300
#
#    Sales Amount
# 0          5000
# 1          2000
# 2           750
# 3           400
# 4           600

# %%
df.to_csv("sample.csv",index = False)

# %%
df["Region"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-46a2f1686c10> in <cell line: 0>()
# ----> 1 df["Region"]
#
# ...
